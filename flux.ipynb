# %%
# !git clone https://github.com/voIatiIe/flux.git

# %%
# %cd /content/flux
# !git pull
# %cd /content

# %%
# !pip install poetry
# !poetry config virtualenvs.in-project true

# %%
# %cd /content/flux
# !poetry install
# %cd /content

# !source /content/flux/.venv/bin/activate

# %%
import sys
sys.path.append('/content/flux/')
sys.path.append('/content/flux/.venv/lib/python3.10/site-packages')

# %%
from flux.models.integrators import (
    UniformSurveyIntegrator,
    FSDPUniformSurveyIntegrator,
)
from flux.models.flows import RepeatedCouplingCellFlow
from flux.models.samplers.samplers import UniformSampler
from flux.models.trainers import VarianceTrainer
from flux.utils.constants import (
    CellType,
    MaskingType,
)
from flux.utils.integrands import GaussIntegrand
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /Users/kmsavelev/Desktop/MSU/flux/flux.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/Users/kmsavelev/Desktop/MSU/flux/flux.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> from flux.models.integrators import (
#       <a href='vscode-notebook-cell:/Users/kmsavelev/Desktop/MSU/flux/flux.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a>     UniformSurveyIntegrator,
#       <a href='vscode-notebook-cell:/Users/kmsavelev/Desktop/MSU/flux/flux.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a>     FSDPUniformSurveyIntegrator,
#       <a href='vscode-notebook-cell:/Users/kmsavelev/Desktop/MSU/flux/flux.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> )
#       <a href='vscode-notebook-cell:/Users/kmsavelev/Desktop/MSU/flux/flux.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> from flux.models.flows import RepeatedCouplingCellFlow
#       <a href='vscode-notebook-cell:/Users/kmsavelev/Desktop/MSU/flux/flux.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a> from flux.models.samplers.samplers import UniformSampler
#
# File ~/Desktop/MSU/flux/flux/models/integrators/__init__.py:1
# ----> 1 from flux.models.integrators.integrators import (
#       2     UniformSurveyIntegrator,
#       3     FSDPUniformSurveyIntegrator,
#       4 )
#       5 from flux.models.integrators.base import BaseIntegrator
#
# File ~/Desktop/MSU/flux/flux/models/integrators/integrators.py:1
# ----> 1 import torch
#       2 import torch.multiprocessing as mp
#       3 import typing as t
#
# File ~/Library/Caches/pypoetry/virtualenvs/flux-qTG5XqLP-py3.10/lib/python3.10/site-packages/torch/__init__.py:234
#     223 else:
#     224     # Easy way.  You want this most of the time, because it will prevent
#     225     # C++ symbols from libtorch clobbering C++ symbols from other
#    (...)
#     231     #
#     232     # See Note [Global dependencies]
#     233     if USE_GLOBAL_DEPS:
# --> 234         _load_global_deps()
#     235     from torch._C import *  # noqa: F403
#     237 # Appease the type checker; ordinarily this binding is inserted by the
#     238 # torch._C module initialization code in C
#
# File ~/Library/Caches/pypoetry/virtualenvs/flux-qTG5XqLP-py3.10/lib/python3.10/site-packages/torch/__init__.py:193, in _load_global_deps()
#     191 is_cuda_lib_err = [lib for lib in cuda_libs.values() if(lib.split('.')[0] in err.args[0])]
#     192 if not is_cuda_lib_err:
# --> 193     raise err
#     194 for lib_folder, lib_name in cuda_libs.items():
#     195     _preload_cuda_deps(lib_folder, lib_name)
#
# File ~/Library/Caches/pypoetry/virtualenvs/flux-qTG5XqLP-py3.10/lib/python3.10/site-packages/torch/__init__.py:174, in _load_global_deps()
#     171 lib_path = os.path.join(os.path.dirname(here), 'lib', lib_name)
#     173 try:
# --> 174     ctypes.CDLL(lib_path, mode=ctypes.RTLD_GLOBAL)
#     175 except OSError as err:
#     176     # Can only happen for wheel with cuda libs as PYPI deps
#     177     # As PyTorch is not purelib, but nvidia-*-cu12 is
#     178     cuda_libs: Dict[str, str] = {
#     179         'cublas': 'libcublas.so.*[0-9]',
#     180         'cudnn': 'libcudnn.so.*[0-9]',
#    (...)
#     189         'nvtx': 'libnvToolsExt.so.*[0-9]',
#     190     }
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ctypes/__init__.py:374, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     371 self._FuncPtr = _FuncPtr
#     373 if handle is None:
# --> 374     self._handle = _dlopen(self._name, mode)
#     375 else:
#     376     self._handle = handle
#
# OSError: dlopen(/Users/kmsavelev/Library/Caches/pypoetry/virtualenvs/flux-qTG5XqLP-py3.10/lib/python3.10/site-packages/torch/lib/libtorch_global_deps.dylib, 0x000A): tried: '/Users/kmsavelev/Library/Caches/pypoetry/virtualenvs/flux-qTG5XqLP-py3.10/lib/python3.10/site-packages/torch/lib/libtorch_global_deps.dylib' (mach-o file, but is an incompatible architecture (have 'x86_64', need 'arm64')), '/System/Volumes/Preboot/Cryptexes/OS/Users/kmsavelev/Library/Caches/pypoetry/virtualenvs/flux-qTG5XqLP-py3.10/lib/python3.10/site-packages/torch/lib/libtorch_global_deps.dylib' (no such file), '/Users/kmsavelev/Library/Caches/pypoetry/virtualenvs/flux-qTG5XqLP-py3.10/lib/python3.10/site-packages/torch/lib/libtorch_global_deps.dylib' (mach-o file, but is an incompatible architecture (have 'x86_64', need 'arm64'))

# %%
def main_parallel():
    dim = 5

    flow = RepeatedCouplingCellFlow(
        dim=dim,
        cell=CellType.PWLINEAR,
        masking=MaskingType.CHECKERBOARD,
        n_cells=2,
    )

    trainer = VarianceTrainer(
        flow=flow,
        prior=UniformSampler(dim=dim)
    )

    integrand = GaussIntegrand(dim=dim)

    integrator = FSDPUniformSurveyIntegrator(
        integrand=integrand,
        trainer=trainer,
        n_points=100000,
    )

    integrator.train(n_refine_steps=10, n_survey_steps=10)

# %%
main_parallel()

# %%
from flux.utils.integrands import GaussIntegrand
from flux.models.integrators.fsdp import integrate

# %%
if __name__ == '__main__':
    integrand = GaussIntegrand(dim=5)
    integrate(integrand)
